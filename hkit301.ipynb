# %% [markdown]
# ## I. Settings
# - 우선 드라이브와 구글 코랩을 마운트할 수 있도록 다음 코드를 순서대로 실행한다.

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)
drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# - 현재 경로를 확인한다.

# %%
# %pwd
# %cd drive/'My Drive'/'Colab Notebooks'
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# - 해당 경로에 `hkit301`폴더를 만드는 것을 추천한다. `mkdir`를 통해서 만들수도 있기도 하지만, 터미널 명령어가 약한 분들을 위해서 사전에 미리 폴더를 만드는 것을 추천한다.
# - `hkit301`로 이동한다.

# %%
# %cd hkit301
# Out:
# /content/drive/My Drive/Colab Notebooks/hkit301

# %% [markdown]
# - 이제 본인의 `git` 계정에 연동하도록 한다.
#   + step 1. `git config --global user.name "your_username"`
#   + step 2. `git config --global user.email "your_email_address"`

# %%
# !git config --global user.name "chloevan"
# !git config --global user.email "j2hoon85@gmail.com"

# %% [markdown]
# - 이제 프로젝트 `Repo`를 다운로드 받는다.
# - 이 소스 코드는 실행시키지 않는다. (향후 새로운 작업을 할 때 실행시킨다.)

# %%
# !git clone https://github.com/hkit301/kaggle.git
# Out:
# Cloning into 'kaggle'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %% [markdown]
# - 파일 작성이 다 끝나면 아래와 같이 코드를 입력한다.

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'My Drive/Colab Notebooks/'

# replace with your github username
GIT_USERNAME = "hkit301"

# definitely replace with your
GIT_TOKEN = "007bb5f5cb4d770834b0763fcd1bf12b4a5f30ea" # this is temporary, whenever you add, need to get token number

# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "kaggle"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)  

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/My Drive/Colab Notebooks/
# GIT_PATH:  https://007bb5f5cb4d770834b0763fcd1bf12b4a5f30ea@github.com/hkit301/kaggle.git

# %%
# !git remote set-url origin "{GIT_PATH}"
# !git add *
# !git commit -m "commit"
# !git push
# Out:
# [master 14a7c0c] commit
#  1720 files changed, 653951 insertions(+), 1 deletion(-)
#  create mode 100644 data/tmdb_5000_credits.csv
#  create mode 100644 data/tmdb_5000_movies.csv
#  rewrite hkit301.ipynb (81%)
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/AUTHORS.rst
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/INSTALLER
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/LICENSE
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/METADATA
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/RECORD
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/WHEEL
#  create mode 100644 python_external_packages/JPype1-0.7.5.dist-info/top_level.txt
#  create mode 100644 python_external_packages/PySocks-1.7.1.dist-info/INSTALLER
#  create mode 100644 python_external_packages/PySocks-1.7.1.dist-info/LICENSE
#  create mode 100644 python_external_packages/PySocks-1.7.1.dist-info/METADATA
#  create mode 100644 python_external_packages/PySocks-1.7.1.dist-info/RECORD
#  create mode 100644 python_external_packages/PySocks-1.7.1.dist-info/WHEEL
#  create mode 100644 python_external_packages/PySocks-1.7.1.dist-info/top_level.txt
#  create mode 100644 python_external_packages/__pycache__/six.cpython-36.pyc
#  create mode 100644 python_external_packages/__pycache__/socks.cpython-36.pyc
#  create mode 100644 python_external_packages/__pycache__/sockshandler.cpython-36.pyc
#  create mode 100644 python_external_packages/_jpype.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/DESCRIPTION.rst
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/INSTALLER
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/METADATA
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/RECORD
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/WHEEL
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/metadata.json
#  create mode 100644 python_external_packages/beautifulsoup4-4.6.0.dist-info/top_level.txt
#  create mode 100644 python_external_packages/bin/chardetect
#  create mode 100644 python_external_packages/bin/f2py
#  create mode 100644 python_external_packages/bin/f2py3
#  create mode 100644 python_external_packages/bin/f2py3.6
#  create mode 100644 python_external_packages/bin/stream_daum
#  create mode 100644 python_external_packages/bin/stream_dcinside
#  create mode 100644 python_external_packages/bin/stream_google
#  create mode 100644 python_external_packages/bin/stream_naver
#  create mode 100644 python_external_packages/bin/stream_twitter
#  create mode 100644 python_external_packages/bs4/__init__.py
#  create mode 100644 python_external_packages/bs4/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/__pycache__/dammit.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/__pycache__/diagnose.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/__pycache__/element.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/__pycache__/testing.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/builder/__init__.py
#  create mode 100644 python_external_packages/bs4/builder/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/builder/__pycache__/_html5lib.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/builder/__pycache__/_htmlparser.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/builder/__pycache__/_lxml.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/builder/_html5lib.py
#  create mode 100644 python_external_packages/bs4/builder/_htmlparser.py
#  create mode 100644 python_external_packages/bs4/builder/_lxml.py
#  create mode 100644 python_external_packages/bs4/dammit.py
#  create mode 100644 python_external_packages/bs4/diagnose.py
#  create mode 100644 python_external_packages/bs4/element.py
#  create mode 100644 python_external_packages/bs4/testing.py
#  create mode 100644 python_external_packages/bs4/tests/__init__.py
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_builder_registry.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_docs.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_html5lib.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_htmlparser.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_lxml.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_soup.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/__pycache__/test_tree.cpython-36.pyc
#  create mode 100644 python_external_packages/bs4/tests/test_builder_registry.py
#  create mode 100644 python_external_packages/bs4/tests/test_docs.py
#  create mode 100644 python_external_packages/bs4/tests/test_html5lib.py
#  create mode 100644 python_external_packages/bs4/tests/test_htmlparser.py
#  create mode 100644 python_external_packages/bs4/tests/test_lxml.py
#  create mode 100644 python_external_packages/bs4/tests/test_soup.py
#  create mode 100644 python_external_packages/bs4/tests/test_tree.py
#  create mode 100644 python_external_packages/certifi-2020.4.5.1.dist-info/INSTALLER
#  create mode 100644 python_external_packages/certifi-2020.4.5.1.dist-info/LICENSE
#  create mode 100644 python_external_packages/certifi-2020.4.5.1.dist-info/METADATA
#  create mode 100644 python_external_packages/certifi-2020.4.5.1.dist-info/RECORD
#  create mode 100644 python_external_packages/certifi-2020.4.5.1.dist-info/WHEEL
#  create mode 100644 python_external_packages/certifi-2020.4.5.1.dist-info/top_level.txt
#  create mode 100644 python_external_packages/certifi/__init__.py
#  create mode 100644 python_external_packages/certifi/__main__.py
#  create mode 100644 python_external_packages/certifi/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/certifi/__pycache__/__main__.cpython-36.pyc
#  create mode 100644 python_external_packages/certifi/__pycache__/core.cpython-36.pyc
#  create mode 100644 python_external_packages/certifi/cacert.pem
#  create mode 100644 python_external_packages/certifi/core.py
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/DESCRIPTION.rst
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/INSTALLER
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/METADATA
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/RECORD
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/WHEEL
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/entry_points.txt
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/metadata.json
#  create mode 100644 python_external_packages/chardet-3.0.4.dist-info/top_level.txt
#  create mode 100644 python_external_packages/chardet/__init__.py
#  create mode 100644 python_external_packages/chardet/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/big5freq.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/big5prober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/chardistribution.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/charsetgroupprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/charsetprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/codingstatemachine.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/compat.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/cp949prober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/enums.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/escprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/escsm.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/eucjpprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/euckrfreq.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/euckrprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/euctwfreq.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/euctwprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/gb2312freq.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/gb2312prober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/hebrewprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/jisfreq.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/jpcntx.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langbulgarianmodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langcyrillicmodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langgreekmodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langhebrewmodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langhungarianmodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langthaimodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/langturkishmodel.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/latin1prober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/mbcharsetprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/mbcsgroupprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/mbcssm.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/sbcharsetprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/sbcsgroupprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/sjisprober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/universaldetector.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/utf8prober.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/__pycache__/version.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/big5freq.py
#  create mode 100644 python_external_packages/chardet/big5prober.py
#  create mode 100644 python_external_packages/chardet/chardistribution.py
#  create mode 100644 python_external_packages/chardet/charsetgroupprober.py
#  create mode 100644 python_external_packages/chardet/charsetprober.py
#  create mode 100644 python_external_packages/chardet/cli/__init__.py
#  create mode 100644 python_external_packages/chardet/cli/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/cli/__pycache__/chardetect.cpython-36.pyc
#  create mode 100644 python_external_packages/chardet/cli/chardetect.py
#  create mode 100644 python_external_packages/chardet/codingstatemachine.py
#  create mode 100644 python_external_packages/chardet/compat.py
#  create mode 100644 python_external_packages/chardet/cp949prober.py
#  create mode 100644 python_external_packages/chardet/enums.py
#  create mode 100644 python_external_packages/chardet/escprober.py
#  create mode 100644 python_external_packages/chardet/escsm.py
#  create mode 100644 python_external_packages/chardet/eucjpprober.py
#  create mode 100644 python_external_packages/chardet/euckrfreq.py
#  create mode 100644 python_external_packages/chardet/euckrprober.py
#  create mode 100644 python_external_packages/chardet/euctwfreq.py
#  create mode 100644 python_external_packages/chardet/euctwprober.py
#  create mode 100644 python_external_packages/chardet/gb2312freq.py
#  create mode 100644 python_external_packages/chardet/gb2312prober.py
#  create mode 100644 python_external_packages/chardet/hebrewprober.py
#  create mode 100644 python_external_packages/chardet/jisfreq.py
#  create mode 100644 python_external_packages/chardet/jpcntx.py
#  create mode 100644 python_external_packages/chardet/langbulgarianmodel.py
#  create mode 100644 python_external_packages/chardet/langcyrillicmodel.py
#  create mode 100644 python_external_packages/chardet/langgreekmodel.py
#  create mode 100644 python_external_packages/chardet/langhebrewmodel.py
#  create mode 100644 python_external_packages/chardet/langhungarianmodel.py
#  create mode 100644 python_external_packages/chardet/langthaimodel.py
#  create mode 100644 python_external_packages/chardet/langturkishmodel.py
#  create mode 100644 python_external_packages/chardet/latin1prober.py
#  create mode 100644 python_external_packages/chardet/mbcharsetprober.py
#  create mode 100644 python_external_packages/chardet/mbcsgroupprober.py
#  create mode 100644 python_external_packages/chardet/mbcssm.py
#  create mode 100644 python_external_packages/chardet/sbcharsetprober.py
#  create mode 100644 python_external_packages/chardet/sbcsgroupprober.py
#  create mode 100644 python_external_packages/chardet/sjisprober.py
#  create mode 100644 python_external_packages/chardet/universaldetector.py
#  create mode 100644 python_external_packages/chardet/utf8prober.py
#  create mode 100644 python_external_packages/chardet/version.py
#  create mode 100644 python_external_packages/colorama-0.4.3.dist-info/INSTALLER
#  create mode 100644 python_external_packages/colorama-0.4.3.dist-info/LICENSE.txt
#  create mode 100644 python_external_packages/colorama-0.4.3.dist-info/METADATA
#  create mode 100644 python_external_packages/colorama-0.4.3.dist-info/RECORD
#  create mode 100644 python_external_packages/colorama-0.4.3.dist-info/WHEEL
#  create mode 100644 python_external_packages/colorama-0.4.3.dist-info/top_level.txt
#  create mode 100644 python_external_packages/colorama/__init__.py
#  create mode 100644 python_external_packages/colorama/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/colorama/__pycache__/ansi.cpython-36.pyc
#  create mode 100644 python_external_packages/colorama/__pycache__/ansitowin32.cpython-36.pyc
#  create mode 100644 python_external_packages/colorama/__pycache__/initialise.cpython-36.pyc
#  create mode 100644 python_external_packages/colorama/__pycache__/win32.cpython-36.pyc
#  create mode 100644 python_external_packages/colorama/__pycache__/winterm.cpython-36.pyc
#  create mode 100644 python_external_packages/colorama/ansi.py
#  create mode 100644 python_external_packages/colorama/ansitowin32.py
#  create mode 100644 python_external_packages/colorama/initialise.py
#  create mode 100644 python_external_packages/colorama/win32.py
#  create mode 100644 python_external_packages/colorama/winterm.py
#  create mode 100644 python_external_packages/idna-2.9.dist-info/INSTALLER
#  create mode 100644 python_external_packages/idna-2.9.dist-info/LICENSE.rst
#  create mode 100644 python_external_packages/idna-2.9.dist-info/METADATA
#  create mode 100644 python_external_packages/idna-2.9.dist-info/RECORD
#  create mode 100644 python_external_packages/idna-2.9.dist-info/WHEEL
#  create mode 100644 python_external_packages/idna-2.9.dist-info/top_level.txt
#  create mode 100644 python_external_packages/idna/__init__.py
#  create mode 100644 python_external_packages/idna/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/codec.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/compat.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/core.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/idnadata.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/intranges.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/package_data.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/__pycache__/uts46data.cpython-36.pyc
#  create mode 100644 python_external_packages/idna/codec.py
#  create mode 100644 python_external_packages/idna/compat.py
#  create mode 100644 python_external_packages/idna/core.py
#  create mode 100644 python_external_packages/idna/idnadata.py
#  create mode 100644 python_external_packages/idna/intranges.py
#  create mode 100644 python_external_packages/idna/package_data.py
#  create mode 100644 python_external_packages/idna/uts46data.py
#  create mode 100644 python_external_packages/jpype/__init__.py
#  create mode 100644 python_external_packages/jpype/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_classpath.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_core.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_gui.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jarray.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jclass.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jcollection.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jcustomizer.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jexception.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jinit.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jio.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jmethod.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jobject.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jpackage.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jproxy.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jstring.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_jvmfinder.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/_pykeywords.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/beans.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/imports.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/nio.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/pickle.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/reflect.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/__pycache__/types.cpython-36.pyc
#  create mode 100644 python_external_packages/jpype/_classpath.py
#  create mode 100644 python_external_packages/jpype/_core.py
#  create mode 100644 python_external_packages/jpype/_gui.py
#  create mode 100644 python_external_packages/jpype/_jarray.py
#  create mode 100644 python_external_packages/jpype/_jclass.py
#  create mode 100644 python_external_packages/jpype/_jcollection.py
#  create mode 100644 python_external_packages/jpype/_jcustomizer.py
#  create mode 100644 python_external_packages/jpype/_jexception.py
#  create mode 100644 python_external_packages/jpype/_jinit.py
#  create mode 100644 python_external_packages/jpype/_jio.py
#  create mode 100644 python_external_packages/jpype/_jmethod.py
#  create mode 100644 python_external_packages/jpype/_jobject.py
#  create mode 100644 python_external_packages/jpype/_jpackage.py
#  create mode 100644 python_external_packages/jpype/_jproxy.py
#  create mode 100644 python_external_packages/jpype/_jstring.py
#  create mode 100644 python_external_packages/jpype/_jvmfinder.py
#  create mode 100644 python_external_packages/jpype/_pykeywords.py
#  create mode 100644 python_external_packages/jpype/beans.py
#  create mode 100644 python_external_packages/jpype/imports.py
#  create mode 100644 python_external_packages/jpype/nio.py
#  create mode 100644 python_external_packages/jpype/pickle.py
#  create mode 100644 python_external_packages/jpype/reflect.py
#  create mode 100644 python_external_packages/jpype/types.py
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/INSTALLER
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/LICENSE
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/METADATA
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/RECORD
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/WHEEL
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/entry_points.txt
#  create mode 100644 python_external_packages/konlpy-0.5.2.dist-info/top_level.txt
#  create mode 100644 python_external_packages/konlpy/__init__.py
#  create mode 100644 python_external_packages/konlpy/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/about.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/constants.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/corpus.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/csvutils.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/data.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/downloader.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/internals.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/jvm.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/__pycache__/utils.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/about.py
#  create mode 100644 python_external_packages/konlpy/constants.py
#  create mode 100644 python_external_packages/konlpy/corpus.py
#  create mode 100644 python_external_packages/konlpy/csvutils.py
#  create mode 100644 python_external_packages/konlpy/data.py
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809890.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809891.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809892.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809893.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809894.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809895.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809896.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809897.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809898.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kobill/1809899.txt
#  create mode 100644 python_external_packages/konlpy/data/corpus/kolaw/constitution.txt
#  create mode 100644 python_external_packages/konlpy/data/tagset/hannanum.json
#  create mode 100644 python_external_packages/konlpy/data/tagset/kkma.json
#  create mode 100644 python_external_packages/konlpy/data/tagset/komoran.json
#  create mode 100644 python_external_packages/konlpy/data/tagset/mecab.json
#  create mode 100644 python_external_packages/konlpy/data/tagset/twitter.json
#  create mode 100644 python_external_packages/konlpy/downloader.py
#  create mode 100644 python_external_packages/konlpy/internals.py
#  create mode 100644 python_external_packages/konlpy/java/aho-corasick.jar
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/jhannanum/comm/HannanumInterface.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/jhannanum/hannanum/WorkflowFactory.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/kkma/KkmaInterface$1.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/kkma/KkmaInterface$2.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/kkma/KkmaInterface$3.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/kkma/KkmaInterface$4.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/kkma/KkmaInterface.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/komoran/KomoranInterface.class
#  create mode 100644 python_external_packages/konlpy/java/bin/kr/lucypark/okt/OktInterface.class
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/MajorPlugin/MorphAnalyzer/ChartMorphAnalyzer.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/MajorPlugin/PosTagger/HmmPosTagger.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/MorphemeProcessor/SimpleMAResult09.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/MorphemeProcessor/SimpleMAResult22.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/MorphemeProcessor/UnknownMorphProcessor.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/PlainTextProcessor/InformalSentenceFilter.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/PlainTextProcessor/SentenceSegmentor.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/PosProcessor/NounExtractor.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/PosProcessor/SimplePOSResult09.json
#  create mode 100644 python_external_packages/konlpy/java/conf/plugin/SupplementPlugin/PosProcessor/SimplePOSResult22.json
#  create mode 100644 python_external_packages/konlpy/java/data/kE/__init__.py
#  create mode 100644 python_external_packages/konlpy/java/data/kE/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/java/data/kE/connections.txt
#  create mode 100644 python_external_packages/konlpy/java/data/kE/connections_not.txt
#  create mode 100644 python_external_packages/konlpy/java/data/kE/dic_analyzed.txt
#  create mode 100644 python_external_packages/konlpy/java/data/kE/dic_system.txt
#  create mode 100644 python_external_packages/konlpy/java/data/kE/dic_user.txt
#  create mode 100644 python_external_packages/konlpy/java/data/kE/tag_set.txt
#  create mode 100644 python_external_packages/konlpy/java/data/models/irregular.model
#  create mode 100644 python_external_packages/konlpy/java/data/models/observation.model
#  create mode 100644 python_external_packages/konlpy/java/data/models/pos.table
#  create mode 100644 python_external_packages/konlpy/java/data/models/transition.model
#  create mode 100644 python_external_packages/konlpy/java/data/stat/PTT.pos
#  create mode 100644 python_external_packages/konlpy/java/data/stat/PTT.wp
#  create mode 100644 python_external_packages/konlpy/java/data/stat/PWT.pos
#  create mode 100644 python_external_packages/konlpy/java/data/stat/__init__.py
#  create mode 100644 python_external_packages/konlpy/java/data/stat/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/java/jhannanum-0.8.4.jar
#  create mode 100644 python_external_packages/konlpy/java/kkma-2.0.jar
#  create mode 100644 python_external_packages/konlpy/java/komoran-3.0.jar
#  create mode 100644 python_external_packages/konlpy/java/open-korean-text-2.1.0.jar
#  create mode 100644 python_external_packages/konlpy/java/scala-library-2.12.3.jar
#  create mode 100644 python_external_packages/konlpy/java/shineware-common-1.0.jar
#  create mode 100644 python_external_packages/konlpy/java/shineware-ds-1.0.jar
#  create mode 100644 python_external_packages/konlpy/java/snakeyaml-1.12.jar
#  create mode 100644 python_external_packages/konlpy/java/twitter-text-1.14.7.jar
#  create mode 100644 python_external_packages/konlpy/jvm.py
#  create mode 100644 python_external_packages/konlpy/stream/__init__.py
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/base.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/daum.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/dcinside.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/google_trend.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/misc.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/naver.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/__pycache__/twitter.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/stream/base.py
#  create mode 100644 python_external_packages/konlpy/stream/daum.py
#  create mode 100644 python_external_packages/konlpy/stream/dcinside.py
#  create mode 100644 python_external_packages/konlpy/stream/google_trend.py
#  create mode 100644 python_external_packages/konlpy/stream/misc.py
#  create mode 100644 python_external_packages/konlpy/stream/naver.py
#  create mode 100644 python_external_packages/konlpy/stream/twitter.py
#  create mode 100644 python_external_packages/konlpy/tag/__init__.py
#  create mode 100644 python_external_packages/konlpy/tag/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/tag/__pycache__/_hannanum.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/tag/__pycache__/_kkma.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/tag/__pycache__/_komoran.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/tag/__pycache__/_mecab.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/tag/__pycache__/_okt.cpython-36.pyc
#  create mode 100644 python_external_packages/konlpy/tag/_hannanum.py
#  create mode 100644 python_external_packages/konlpy/tag/_kkma.py
#  create mode 100644 python_external_packages/konlpy/tag/_komoran.py
#  create mode 100644 python_external_packages/konlpy/tag/_mecab.py
#  create mode 100644 python_external_packages/konlpy/tag/_okt.py
#  create mode 100644 python_external_packages/konlpy/utils.py
#  create mode 100644 python_external_packages/lxml-4.5.1.dist-info/INSTALLER
#  create mode 100644 python_external_packages/lxml-4.5.1.dist-info/METADATA
#  create mode 100644 python_external_packages/lxml-4.5.1.dist-info/RECORD
#  create mode 100644 python_external_packages/lxml-4.5.1.dist-info/WHEEL
#  create mode 100644 python_external_packages/lxml-4.5.1.dist-info/top_level.txt
#  create mode 100644 python_external_packages/lxml/ElementInclude.py
#  create mode 100644 python_external_packages/lxml/__init__.py
#  create mode 100644 python_external_packages/lxml/__pycache__/ElementInclude.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/_elementpath.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/builder.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/cssselect.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/doctestcompare.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/pyclasslookup.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/sax.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/__pycache__/usedoctest.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/_elementpath.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/_elementpath.py
#  create mode 100644 python_external_packages/lxml/builder.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/builder.py
#  create mode 100644 python_external_packages/lxml/cssselect.py
#  create mode 100644 python_external_packages/lxml/doctestcompare.py
#  create mode 100644 python_external_packages/lxml/etree.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/etree.h
#  create mode 100644 python_external_packages/lxml/etree_api.h
#  create mode 100644 python_external_packages/lxml/html/ElementSoup.py
#  create mode 100644 python_external_packages/lxml/html/__init__.py
#  create mode 100644 python_external_packages/lxml/html/__pycache__/ElementSoup.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/_diffcommand.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/_html5builder.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/_setmixin.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/builder.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/clean.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/defs.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/diff.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/formfill.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/html5parser.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/soupparser.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/__pycache__/usedoctest.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/html/_diffcommand.py
#  create mode 100644 python_external_packages/lxml/html/_html5builder.py
#  create mode 100644 python_external_packages/lxml/html/_setmixin.py
#  create mode 100644 python_external_packages/lxml/html/builder.py
#  create mode 100644 python_external_packages/lxml/html/clean.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/html/clean.py
#  create mode 100644 python_external_packages/lxml/html/defs.py
#  create mode 100644 python_external_packages/lxml/html/diff.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/html/diff.py
#  create mode 100644 python_external_packages/lxml/html/formfill.py
#  create mode 100644 python_external_packages/lxml/html/html5parser.py
#  create mode 100644 python_external_packages/lxml/html/soupparser.py
#  create mode 100644 python_external_packages/lxml/html/usedoctest.py
#  create mode 100644 python_external_packages/lxml/includes/__init__.pxd
#  create mode 100644 python_external_packages/lxml/includes/__init__.py
#  create mode 100644 python_external_packages/lxml/includes/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/includes/c14n.pxd
#  create mode 100644 python_external_packages/lxml/includes/config.pxd
#  create mode 100644 python_external_packages/lxml/includes/dtdvalid.pxd
#  create mode 100644 python_external_packages/lxml/includes/etree_defs.h
#  create mode 100644 python_external_packages/lxml/includes/etreepublic.pxd
#  create mode 100644 python_external_packages/lxml/includes/htmlparser.pxd
#  create mode 100644 python_external_packages/lxml/includes/libexslt/exslt.h
#  create mode 100644 python_external_packages/lxml/includes/libexslt/exsltconfig.h
#  create mode 100644 python_external_packages/lxml/includes/libexslt/exsltexports.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/DOCBparser.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/HTMLparser.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/HTMLtree.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/SAX.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/SAX2.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/c14n.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/catalog.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/chvalid.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/debugXML.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/dict.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/encoding.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/entities.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/globals.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/hash.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/list.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/nanoftp.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/nanohttp.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/parser.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/parserInternals.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/relaxng.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/schemasInternals.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/schematron.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/threads.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/tree.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/uri.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/valid.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xinclude.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xlink.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlIO.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlautomata.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlerror.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlexports.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlmemory.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlmodule.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlreader.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlregexp.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlsave.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlschemas.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlschemastypes.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlstring.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlunicode.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlversion.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xmlwriter.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xpath.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xpathInternals.h
#  create mode 100644 python_external_packages/lxml/includes/libxml/xpointer.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/attributes.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/documents.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/extensions.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/extra.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/functions.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/imports.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/keys.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/namespaces.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/numbersInternals.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/pattern.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/preproc.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/security.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/templates.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/transform.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/variables.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/xslt.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/xsltInternals.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/xsltconfig.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/xsltexports.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/xsltlocale.h
#  create mode 100644 python_external_packages/lxml/includes/libxslt/xsltutils.h
#  create mode 100644 python_external_packages/lxml/includes/lxml-version.h
#  create mode 100644 python_external_packages/lxml/includes/relaxng.pxd
#  create mode 100644 python_external_packages/lxml/includes/schematron.pxd
#  create mode 100644 python_external_packages/lxml/includes/tree.pxd
#  create mode 100644 python_external_packages/lxml/includes/uri.pxd
#  create mode 100644 python_external_packages/lxml/includes/xinclude.pxd
#  create mode 100644 python_external_packages/lxml/includes/xmlerror.pxd
#  create mode 100644 python_external_packages/lxml/includes/xmlparser.pxd
#  create mode 100644 python_external_packages/lxml/includes/xmlschema.pxd
#  create mode 100644 python_external_packages/lxml/includes/xpath.pxd
#  create mode 100644 python_external_packages/lxml/includes/xslt.pxd
#  create mode 100644 python_external_packages/lxml/isoschematron/__init__.py
#  create mode 100644 python_external_packages/lxml/isoschematron/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/rng/iso-schematron.rng
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl
#  create mode 100644 python_external_packages/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt
#  create mode 100644 python_external_packages/lxml/lxml.etree.h
#  create mode 100644 python_external_packages/lxml/lxml.etree_api.h
#  create mode 100644 python_external_packages/lxml/objectify.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/pyclasslookup.py
#  create mode 100644 python_external_packages/lxml/sax.cpython-36m-x86_64-linux-gnu.so
#  create mode 100644 python_external_packages/lxml/sax.py
#  create mode 100644 python_external_packages/lxml/usedoctest.py
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/INSTALLER
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/LICENSE.txt
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/LICENSES_bundled.txt
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/METADATA
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/RECORD
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/WHEEL
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/entry_points.txt
#  create mode 100644 python_external_packages/numpy-1.18.4.dist-info/top_level.txt
#  create mode 100644 python_external_packages/numpy.libs/libgfortran-ed201abd.so.3.0.0
#  create mode 100644 python_external_packages/numpy.libs/libopenblasp-r0-34a18dc3.3.7.so
#  create mode 100644 python_external_packages/numpy/LICENSE.txt
#  create mode 100644 python_external_packages/numpy/__config__.py
#  create mode 100644 python_external_packages/numpy/__init__.py
#  create mode 100644 python_external_packages/numpy/__pycache__/__config__.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/_distributor_init.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/_globals.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/_pytesttester.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/conftest.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/ctypeslib.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/dual.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/matlib.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/setup.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/__pycache__/version.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/_distributor_init.py
#  create mode 100644 python_external_packages/numpy/_globals.py
#  create mode 100644 python_external_packages/numpy/_pytesttester.py
#  create mode 100644 python_external_packages/numpy/compat/__init__.py
#  create mode 100644 python_external_packages/numpy/compat/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/compat/__pycache__/_inspect.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/compat/__pycache__/py3k.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/compat/__pycache__/setup.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/compat/_inspect.py
#  create mode 100644 python_external_packages/numpy/compat/py3k.py
#  create mode 100644 python_external_packages/numpy/compat/setup.py
#  create mode 100644 python_external_packages/numpy/compat/tests/__init__.py
#  create mode 100644 python_external_packages/numpy/compat/tests/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/compat/tests/__pycache__/test_compat.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/compat/tests/test_compat.py
#  create mode 100644 python_external_packages/numpy/conftest.py
#  create mode 100644 python_external_packages/numpy/core/__init__.py
#  create mode 100644 python_external_packages/numpy/core/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_add_newdocs.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_asarray.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_dtype.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_dtype_ctypes.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_exceptions.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_internal.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_methods.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_string_helpers.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_type_aliases.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/_ufunc_config.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/arrayprint.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/cversions.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/defchararray.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/einsumfunc.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/fromnumeric.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/function_base.cpython-36.pyc
#  create mode 100644 python_external_packages/numpy/core/__pycache__/generate_numpy_api.cpython-36.pyc
# ...
#  create mode 100644 python_external_packages/requests-2.23.0.dist-info/WHEEL
#  create mode 100644 python_external_packages/requests-2.23.0.dist-info/top_level.txt
#  create mode 100644 python_external_packages/requests/__init__.py
#  create mode 100644 python_external_packages/requests/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/__version__.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/_internal_utils.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/adapters.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/api.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/auth.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/certs.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/compat.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/cookies.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/exceptions.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/help.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/hooks.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/models.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/packages.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/sessions.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/status_codes.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/structures.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__pycache__/utils.cpython-36.pyc
#  create mode 100644 python_external_packages/requests/__version__.py
#  create mode 100644 python_external_packages/requests/_internal_utils.py
#  create mode 100644 python_external_packages/requests/adapters.py
#  create mode 100644 python_external_packages/requests/api.py
#  create mode 100644 python_external_packages/requests/auth.py
#  create mode 100644 python_external_packages/requests/certs.py
#  create mode 100644 python_external_packages/requests/compat.py
#  create mode 100644 python_external_packages/requests/cookies.py
#  create mode 100644 python_external_packages/requests/exceptions.py
#  create mode 100644 python_external_packages/requests/help.py
#  create mode 100644 python_external_packages/requests/hooks.py
#  create mode 100644 python_external_packages/requests/models.py
#  create mode 100644 python_external_packages/requests/packages.py
#  create mode 100644 python_external_packages/requests/sessions.py
#  create mode 100644 python_external_packages/requests/status_codes.py
#  create mode 100644 python_external_packages/requests/structures.py
#  create mode 100644 python_external_packages/requests/utils.py
#  create mode 100644 python_external_packages/requests_oauthlib-1.3.0.dist-info/INSTALLER
#  create mode 100644 python_external_packages/requests_oauthlib-1.3.0.dist-info/LICENSE
#  create mode 100644 python_external_packages/requests_oauthlib-1.3.0.dist-info/METADATA
#  create mode 100644 python_external_packages/requests_oauthlib-1.3.0.dist-info/RECORD
#  create mode 100644 python_external_packages/requests_oauthlib-1.3.0.dist-info/WHEEL
#  create mode 100644 python_external_packages/requests_oauthlib-1.3.0.dist-info/top_level.txt
#  create mode 100644 python_external_packages/requests_oauthlib/__init__.py
#  create mode 100644 python_external_packages/requests_oauthlib/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/__pycache__/oauth1_auth.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/__pycache__/oauth1_session.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/__pycache__/oauth2_auth.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/__pycache__/oauth2_session.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__init__.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/douban.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/facebook.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/fitbit.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/instagram.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/linkedin.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/mailchimp.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/plentymarkets.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/slack.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/__pycache__/weibo.cpython-36.pyc
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/douban.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/facebook.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/fitbit.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/instagram.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/linkedin.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/mailchimp.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/plentymarkets.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/slack.py
#  create mode 100644 python_external_packages/requests_oauthlib/compliance_fixes/weibo.py
#  create mode 100644 python_external_packages/requests_oauthlib/oauth1_auth.py
#  create mode 100644 python_external_packages/requests_oauthlib/oauth1_session.py
#  create mode 100644 python_external_packages/requests_oauthlib/oauth2_auth.py
#  create mode 100644 python_external_packages/requests_oauthlib/oauth2_session.py
#  create mode 100644 python_external_packages/six-1.15.0.dist-info/INSTALLER
#  create mode 100644 python_external_packages/six-1.15.0.dist-info/LICENSE
#  create mode 100644 python_external_packages/six-1.15.0.dist-info/METADATA
#  create mode 100644 python_external_packages/six-1.15.0.dist-info/RECORD
#  create mode 100644 python_external_packages/six-1.15.0.dist-info/WHEEL
#  create mode 100644 python_external_packages/six-1.15.0.dist-info/top_level.txt
#  create mode 100644 python_external_packages/six.py
#  create mode 100644 python_external_packages/socks.py
#  create mode 100644 python_external_packages/sockshandler.py
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/INSTALLER
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/LICENSE
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/METADATA
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/RECORD
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/WHEEL
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/top_level.txt
#  create mode 100644 python_external_packages/tweepy-3.8.0.dist-info/zip-safe
#  create mode 100644 python_external_packages/tweepy/__init__.py
#  create mode 100644 python_external_packages/tweepy/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/api.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/auth.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/binder.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/cache.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/cursor.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/error.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/models.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/parsers.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/streaming.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/__pycache__/utils.cpython-36.pyc
#  create mode 100644 python_external_packages/tweepy/api.py
#  create mode 100644 python_external_packages/tweepy/auth.py
#  create mode 100644 python_external_packages/tweepy/binder.py
#  create mode 100644 python_external_packages/tweepy/cache.py
#  create mode 100644 python_external_packages/tweepy/cursor.py
#  create mode 100644 python_external_packages/tweepy/error.py
#  create mode 100644 python_external_packages/tweepy/models.py
#  create mode 100644 python_external_packages/tweepy/parsers.py
#  create mode 100644 python_external_packages/tweepy/streaming.py
#  create mode 100644 python_external_packages/tweepy/utils.py
#  create mode 100644 python_external_packages/urllib3-1.25.9.dist-info/INSTALLER
#  create mode 100644 python_external_packages/urllib3-1.25.9.dist-info/LICENSE.txt
#  create mode 100644 python_external_packages/urllib3-1.25.9.dist-info/METADATA
#  create mode 100644 python_external_packages/urllib3-1.25.9.dist-info/RECORD
#  create mode 100644 python_external_packages/urllib3-1.25.9.dist-info/WHEEL
#  create mode 100644 python_external_packages/urllib3-1.25.9.dist-info/top_level.txt
#  create mode 100644 python_external_packages/urllib3/__init__.py
#  create mode 100644 python_external_packages/urllib3/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/_collections.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/connection.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/connectionpool.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/exceptions.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/fields.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/filepost.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/poolmanager.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/request.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/__pycache__/response.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/_collections.py
#  create mode 100644 python_external_packages/urllib3/connection.py
#  create mode 100644 python_external_packages/urllib3/connectionpool.py
#  create mode 100644 python_external_packages/urllib3/contrib/__init__.py
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/_appengine_environ.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/appengine.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/ntlmpool.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/pyopenssl.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/securetransport.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/__pycache__/socks.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/_appengine_environ.py
#  create mode 100644 python_external_packages/urllib3/contrib/_securetransport/__init__.py
#  create mode 100644 python_external_packages/urllib3/contrib/_securetransport/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/_securetransport/__pycache__/bindings.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/_securetransport/__pycache__/low_level.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/contrib/_securetransport/bindings.py
#  create mode 100644 python_external_packages/urllib3/contrib/_securetransport/low_level.py
#  create mode 100644 python_external_packages/urllib3/contrib/appengine.py
#  create mode 100644 python_external_packages/urllib3/contrib/ntlmpool.py
#  create mode 100644 python_external_packages/urllib3/contrib/pyopenssl.py
#  create mode 100644 python_external_packages/urllib3/contrib/securetransport.py
#  create mode 100644 python_external_packages/urllib3/contrib/socks.py
#  create mode 100644 python_external_packages/urllib3/exceptions.py
#  create mode 100644 python_external_packages/urllib3/fields.py
#  create mode 100644 python_external_packages/urllib3/filepost.py
#  create mode 100644 python_external_packages/urllib3/packages/__init__.py
#  create mode 100644 python_external_packages/urllib3/packages/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/packages/__pycache__/six.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/packages/backports/__init__.py
#  create mode 100644 python_external_packages/urllib3/packages/backports/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/packages/backports/__pycache__/makefile.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/packages/backports/makefile.py
#  create mode 100644 python_external_packages/urllib3/packages/six.py
#  create mode 100644 python_external_packages/urllib3/packages/ssl_match_hostname/__init__.py
#  create mode 100644 python_external_packages/urllib3/packages/ssl_match_hostname/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/packages/ssl_match_hostname/__pycache__/_implementation.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/packages/ssl_match_hostname/_implementation.py
#  create mode 100644 python_external_packages/urllib3/poolmanager.py
#  create mode 100644 python_external_packages/urllib3/request.py
#  create mode 100644 python_external_packages/urllib3/response.py
#  create mode 100644 python_external_packages/urllib3/util/__init__.py
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/__init__.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/connection.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/queue.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/request.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/response.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/retry.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/ssl_.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/timeout.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/url.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/__pycache__/wait.cpython-36.pyc
#  create mode 100644 python_external_packages/urllib3/util/connection.py
#  create mode 100644 python_external_packages/urllib3/util/queue.py
#  create mode 100644 python_external_packages/urllib3/util/request.py
#  create mode 100644 python_external_packages/urllib3/util/response.py
#  create mode 100644 python_external_packages/urllib3/util/retry.py
#  create mode 100644 python_external_packages/urllib3/util/ssl_.py
#  create mode 100644 python_external_packages/urllib3/util/timeout.py
#  create mode 100644 python_external_packages/urllib3/util/url.py
#  create mode 100644 python_external_packages/urllib3/util/wait.py
# fatal: could not read Password for 'https://007bb5f5cb4d770834b0763fcd1bf12b4a5f30ea@github.com': No such device or address

# %% [markdown]
# ## II. Branch 생성 및 이동
# - 우선 `kaggle` 폴더로 이동한다.

# %%
# %cd kaggle
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/hkit301/kaggle
# hajin  hkit301.ipynb  jongmin  README.md  sungsik

# %%
# !ls
# Out:
# hajin  hkit301.ipynb  jongmin  python_external_packages  README.md  seongsik

# %% [markdown]
# ### (1) 브랜치 생성 (주 사용자만 해당)
# - 브랜치 이름을 생성한다.
# - 브랜치 이름은 슬래시(/)를 사용하여 계층적인 구조로 만들어서 사용할 수 있으며, 작성 규칙은 다음과 같다.
#   + 기호(-)로 시작할 수 없다.
#   + 연속적인 마침표(..)를 포함할 수 없다.
#   + 빈간, 공백 문자, 물결(~), 캐럿(^), 물음표(?), 별표(*), 대괄호([]) 등은 포함할 수 없다.
#   + 브랜치 이름은 중복해서 사용할 수 없다.

# %%
# !git branch hajin

# %%
# !git branch jongmin

# %%
# !git branch seongsik

# %% [markdown]
# ### (2) 브랜치 확인
# - 브랜치 목록을 확인하는 방법은 매우 간단하다.

# %%
# !git branch
# Out:
#   hajin
#   jongmin
# * master
#   seongsik

# %% [markdown]
# - 여기에서 `별표(*)`는 현재 선택된 브랜치를 의미한다.
# - 브랜치의 세부 사항을 확인하기 위해서는 `git branch -v`를 실행한다.

# %%
# !git branch -v
# Out:
#   hajin    cc21763 commit
#   jongmin  cc21763 commit
# * master   cc21763 commit
#   seongsik cc21763 commit

# %% [markdown]
# ### (3) 브랜치 이동 및 작업 예제
# - checkout 명령어는 호텔에서 퇴실할 때의 체크아웃을 떠올리면 이해하기 쉬울 것이다.
# - 지금 현재 `master` 상태에서 이제 각각의 브랜치로 이동하도록 한다.
# - 이 때, 중요한 것은 팀프로젝트이지만, 각각의 폴더로 이동 후 `git checkout` 을 실행하는 것을 권한다.
# - 우선 `hajin`의 예를 들면 다음과 같다.
#   + 먼저 구글 코랩 `CELL`안에서 `%cd hajin` 실행하여 이동한다.

# %%
# %cd hajin/
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/hkit301/kaggle/hajin
# hajin_WBS.md

# %% [markdown]
# - 실제로 이동이 되었는지 확인한다.

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/hkit301/kaggle/hajin'

# %% [markdown]
# - 이제 `git checkout hajin`을 실행한다.

# %%
# !git checkout hajin
# Out:
# M	hkit301.ipynb
# D	setting.ipynb
# D	sungsik/sungsik_WBS.md
# Switched to branch 'hajin'

# %% [markdown]
# - `Switched to branch 'hajin'`으로 변경된 것을 확인할 수 있다.
# - 변경된 브랜치에서 작업하면 된다.
# - 간단하게 `temp.ipynb`를 생성했다.

# %%
# !ls
# Out:
# hajin_WBS.md  temp.ipynb

# %% [markdown]
# ### (4) 원격 저장소에 push 하기
# - 현재 로컬에서만 `branch`를 생성한 상태이기 때문에 아래 명령을 입력해서 upstream branch로 만들어준다.
# - master의 remote 정보를 새로운 브랜치에도 그대로 가져온다.

# %%
# !git push --set-upstream origin hajin
# Out:
# Total 0 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'hajin' on GitHub by visiting:
# remote:      https://github.com/hkit301/kaggle/pull/new/hajin
# remote:
# To https://github.com/hkit301/kaggle.git
#  * [new branch]      hajin -> hajin
# Branch 'hajin' set up to track remote branch 'hajin' from 'origin'.

# %% [markdown]
# - 이렇게 한번 `upstream`을 진행한 이후에는 `git add .`와 `git commit -m "your_message"` 명령어만 입력하면 된다.

# %%
# !git add .
# !git commit -m "hajin commit"
# Out:
# ^C
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Changes not staged for commit:
# 	modified:   hkit301.ipynb
# 	deleted:    setting.ipynb
# 	deleted:    sungsik/sungsik_WBS.md
#
# Untracked files:
# 	.gitignore.md
# 	python_external_packages/
#
# no changes added to commit

# %% [markdown]
# ### (4) 브랜치 병합 및 마지막 커밋(주 사용자가 실행)
# - 이제 `checkout master`로 들어간 이후에 병합과 최종 push를 진행한다.
# - `git merge`를 할 때에는 꼭 자신의 `branch 이름`을 명기해야 한다.
#   + `!git merge hajin`
#   + `!git merge jongmin`
#   + `!git merge seongsik`

# %%
# !git checkout master
# !git merge hajin
# Out:
# M	hkit301.ipynb
# D	setting.ipynb
# D	sungsik/sungsik_WBS.md
# Switched to branch 'master'
# Your branch is up to date with 'origin/master'.
# Updating cc21763..e91d409
# Fast-forward
#  hajin/temp.ipynb | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 hajin/temp.ipynb

# %% [markdown]
# - 이제 최종적인 `push`만 남았다.

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 593 bytes | 148.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/hkit301/kaggle.git
#    cc21763..e91d409  master -> master

# %%
# %cd ..
# %ls
# Out:
# /content/drive/My Drive/Colab Notebooks/hkit301/kaggle
# hajin/  hkit301.ipynb  jongmin/  README.md  seongsik/

# %%
# !git add *
# !git commit -m "commit"
# !git push origin master
# Out:
# [master af9a9b3] commit
#  1 file changed, 151 insertions(+)
# fatal: could not read Password for 'https://42971973bda7ff1c65d0981d86a124b6bbb7c193@github.com': No such device or address

# %% [markdown]
# - 이제 이와 같은 방식으로 진행하면 된다.

# %% [markdown]
# ## III. 외부 패키지 설치 및 관리
# - 구글 Colab에서 패키지 세팅과 관련된 문서는 [Python Package Settings on Google Colab](https://chloevan.github.io/settings/colab_package_settings/)을 참조한다.

# %% [markdown]
# ### (1) 외부 패키지 설치
# - 아래 소스코드를 실행한다. 이 때 중요한 것은 결국 경로다.

# %%
import os, sys
from google.colab import drive
drive.mount('/content/mnt')
my_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks/hkit301/kaggle/python_external_packages', my_path)
sys.path.insert(0,my_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/mnt

# %% [markdown]
# - 한글 형태소 관련 패키지인 `konlpy`를 설치해보자.

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk 
# !pip3 install --target=$my_path konlpy
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,819 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [854 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,228 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [931 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,385 kB]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [877 kB]
# Fetched 7,366 kB in 3s (2,515 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# g++ set to manually installed.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxxf86dga1 openjdk-8-jdk-headless openjdk-8-jre
#   openjdk-8-jre-headless x11-utils
# Suggested packages:
#   openjdk-8-demo openjdk-8-source visualvm icedtea-8-plugin libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxxf86dga1 openjdk-8-jdk openjdk-8-jdk-headless
#   openjdk-8-jre openjdk-8-jre-headless x11-utils
# 0 upgraded, 10 newly installed, 0 to remove and 39 not upgraded.
# Need to get 40.7 MB of archives.
# After this operation, 153 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u252-b09-1~18.04 [27.5 MB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre amd64 8u252-b09-1~18.04 [69.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk-headless amd64 8u252-b09-1~18.04 [8,250 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk amd64 8u252-b09-1~18.04 [1,622 kB]
# Fetched 40.7 MB in 2s (20.4 MB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 144439 files and directories currently installed.)
# Preparing to unpack .../0-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../1-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../2-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../3-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../4-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../5-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../6-openjdk-8-jre-headless_8u252-b09-1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u252-b09-1~18.04) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../7-openjdk-8-jre_8u252-b09-1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u252-b09-1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../8-openjdk-8-jdk-headless_8u252-b09-1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u252-b09-1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk:amd64.
# Preparing to unpack .../9-openjdk-8-jdk_8u252-b09-1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk:amd64 (8u252-b09-1~18.04) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u252-b09-1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up openjdk-8-jdk-headless:amd64 (8u252-b09-1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode
# Setting up x11-utils (7.7+3build1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u252-b09-1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up openjdk-8-jdk:amd64 (8u252-b09-1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/appletviewer to provide /usr/bin/appletviewer (appletviewer) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 11.6MB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting numpy>=1.6
#   Downloading https://files.pythonhosted.org/packages/03/27/e35e7c6e6a52fab9fcc64fc2b20c6b516eba930bb02b10ace3b38200d3ab/numpy-1.18.4-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#      |████████████████████████████████| 20.2MB 1.3MB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/2d/9b/e115101a833605b3c0e6f3a2bc1f285c95aaa1d93ab808314ca1bde63eed/JPype1-0.7.5-cp36-cp36m-manylinux2010_x86_64.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 36.0MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 9.1MB/s
# Collecting lxml>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/55/6f/c87dffdd88a54dd26a3a9fef1d14b6384a9933c455c54ce3ca7d64a84c88/lxml-4.5.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 32.8MB/s
# Collecting requests>=2.11.1
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 6.8MB/s
# Collecting requests-oauthlib>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting PySocks>=1.5.7
#   Downloading https://files.pythonhosted.org/packages/8d/59/b4572118e098ac8e46e399a1dd0f2d85403ce8bbaad9ec79373ed6badaf9/PySocks-1.7.1-py3-none-any.whl
# Collecting six>=1.10.0
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/e1/e5/df302e8017440f111c11cc41a6b432838672f5a70aa29227bf58149dc72f/urllib3-1.25.9-py2.py3-none-any.whl (126kB)
#      |████████████████████████████████| 133kB 48.3MB/s
# Collecting chardet<4,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 49.2MB/s
# Collecting certifi>=2017.4.17
#   Downloading https://files.pythonhosted.org/packages/57/2b/26e37a4b034800c960a00c4e1b3d9ca5d7014e983e6e729e33ea2f36426c/certifi-2020.4.5.1-py2.py3-none-any.whl (157kB)
#      |████████████████████████████████| 163kB 45.0MB/s
# Collecting idna<3,>=2.5
#   Downloading https://files.pythonhosted.org/packages/89/e3/afebe61c546d18fb1709a61bee788254b40e736cff7271c7de5de2dc4128/idna-2.9-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 7.0MB/s
# Collecting oauthlib>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
#      |████████████████████████████████| 153kB 49.3MB/s
# ERROR: kaggle 1.5.6 has requirement urllib3<1.25,>=1.21.1, but you'll have urllib3 1.25.9 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.15.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: urllib3, chardet, certifi, idna, requests, oauthlib, requests-oauthlib, PySocks, six, tweepy, colorama, numpy, JPype1, beautifulsoup4, lxml, konlpy
# Successfully installed JPype1-0.7.5 PySocks-1.7.1 beautifulsoup4-4.6.0 certifi-2020.4.5.1 chardet-3.0.4 colorama-0.4.3 idna-2.9 konlpy-0.5.2 lxml-4.5.1 numpy-1.18.4 oauthlib-3.1.0 requests-2.23.0 requests-oauthlib-1.3.0 six-1.15.0 tweepy-3.8.0 urllib3-1.25.9

# %% [markdown]
# - 설치 후에, `Google Drive`에서 설치가 되었는지 꼭 확인해본다.
# - 이제 `Sample Code`를 실행하여 정상적으로 설치가 되었는지 재차 확인한다.

# %%
from konlpy.tag import Twitter

twitter = Twitter()
twitter.pos("질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요")
# Out:
# /content/notebooks/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [('질문', 'Noun'),
#  ('이나', 'Josa'),
#  ('건의', 'Noun'),
#  ('사항', 'Noun'),
#  ('은', 'Josa'),
#  ('깃', 'Noun'),
#  ('헙', 'Verb'),
#  ('이슈', 'Noun'),
#  ('트래커', 'Noun'),
#  ('에', 'Josa'),
#  ('남겨주세요', 'Verb')]

# %% [markdown]
# ## IV. 데이터셋 및 패키지 폴더 관리
# - 대용량의 데이터셋은 모두 구글 드라이브에 올려서 작업하는 것을 권장한다.
# - 다만 데이터를 불러올 때는 아래 코드를 따라서 각 개인 폴더에서 불러오면 된다.

# %% [markdown]
# ### (1) 데이터셋 연동
# - 각 데이터는 모두 `data` 폴더에 올려놓도록 한다.

# %%
# !ls
# Out:
# data   hkit301.ipynb  python_external_packages	seongsik
# hajin  jongmin	      README.md

# %%
import pandas as pd 

credits = pd.read_csv('data/tmdb_5000_credits.csv')
credits.head(5)
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
movies = pd.read_csv('data/tmdb_5000_movies.csv')
movies.head(5)
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %% [markdown]
# - 정상적으로 불러온 것을 확인할 수 있다.

# %% [markdown]
# ### (2) .gitignore 파일 작성
# - 100MB 이상의 데이터가 올라가는 방지 하기 위해 패키지 폴더와 모든 `.json & .csv 파일`은 깃허브에 업데이트 되지 않도록 파일을 작성하였다.
#
# ```
# # exclude data files
# *.json
# *.csv
#
# # ignore package folder
# python_external_packages/
# ```
